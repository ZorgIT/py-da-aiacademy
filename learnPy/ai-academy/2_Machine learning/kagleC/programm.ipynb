# %%
import pandas as pd #Подключаем модуль пандас
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('train.csv') #загружаем тренировочный датасет

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape #смотрим размерность
# Out:
# (1000, 81)

# %%
import numpy as np

# %%
# УЛУЧШЕНИЕ Создание словаря для замены категорий на числа


"""
alley_mapping = {
    'Grvl':1,
    'Pave':2,
    'NA':3
}
df['AlleyNumeric'] = df['Alley'].map(alley_mapping)

neighborhood_mapping = {
    'CollgCr': 1,
    'NWAmes': 2,
    'OldTown': 3,
    'Bluest': 4
}

df['NeighborhoodNumeric'] = df['Neighborhood'].map(neighborhood_mapping)
"""
zoning_mapping = {
    'A': 1,
    'C': 2,
    'FV': 3,
    'I': 4,
    'RH': 5,
    'RL': 6,
    'RP': 7,
    'RM': 8
}
street_mapping = {
    'Grvl':1,
    'Pave':2
}
lotShape_mapping = {
    'Reg':1,
    'IR1':2,
    'IR2':3,
    'IR3':4
}
utilities_mapping = {'AllPub': 1, 'NoSewr': 2, 'NoSeWa': 3, 'ELO': 4}
lot_config_mapping = {'Inside': 1, 'Corner': 2, 'CulDSac': 3, 'FR2': 4}
house_style_mapping = {
    'SLv': 1, '1.5Unf': 2, '1Story': 3, '2Story': 4,
    '1.5Fin': 5, '2.5Fin': 6, '2.5Unf': 7, 'SFoyer': 8, 'SLog': 9
}
bldg_type_mapping = {
    '1Fam': 1, '2FmCon': 2, 'Duplex': 3, 'TwnhsE': 4,
    'Twnhs': 5, '1.5Unf': 6, '2.5Unf': 7, '2.5Fin': 8
}
df['ZoningNumeric'] = df['MSZoning'].map(zoning_mapping)
df['StreetNumeric'] = df['Street'].map(street_mapping)
df['LotShapeNumeric'] = df['LotShape'].map(lotShape_mapping)
df['UtilitiesNumeric'] = df['Utilities'].map(utilities_mapping)
df['LotConfigNumeric'] = df['LotConfig'].map(lot_config_mapping)
df['HouseStyleNumeric'] = df['HouseStyle'].map(house_style_mapping)
df['BldgTypeNumeric'] = df['BldgType'].map(bldg_type_mapping)

# %%
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate #подключение разбиения, кросс валидация
from sklearn.metrics import mean_squared_error, make_scorer #подключаем метрики для оценки ошибки MSE

# %%
#Разбиение на тренировочный датасет и проверочный, размер деления 80 на 20
X_train, X_test, y_train, y_test = train_test_split(df.drop('SalePrice', axis=1), df['SalePrice'], test_size=0.2)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (800, 87) (200, 87)

# %%
#Заполняем пропущенные данные средними значениями
X_train['LotFrontage'] = X_train['LotFrontage'].fillna(df['LotFrontage'].mean())
X_test['LotFrontage'] = X_test['LotFrontage'].fillna(df['LotFrontage'].mean())
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
#Заполняем пропущенные данные средними значениями
X_train['MasVnrArea'] = X_train['MasVnrArea'].fillna(df['MasVnrArea'].mean())
X_test['MasVnrArea'] = X_test['MasVnrArea'].fillna(df['MasVnrArea'].mean())
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
#Заполняем пропущенные данные средними значениями
X_train['ZoningNumeric'] = X_train['ZoningNumeric'].fillna(df['ZoningNumeric'].mean())
X_test['ZoningNumeric'] = X_test['ZoningNumeric'].fillna(df['ZoningNumeric'].mean())
df['ZoningNumeric'] = df['ZoningNumeric'].fillna(df['ZoningNumeric'].mean())

# %%
X_train['LotFrontage'] = X_train['LotFrontage'].fillna(df['LotFrontage'].mean())
X_test['LotFrontage'] = X_test['LotFrontage'].fillna(df['LotFrontage'].mean())
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
X_train['GarageYrBlt'] = X_train['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())
X_test['GarageYrBlt'] = X_test['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
X_train['BldgTypeNumeric'] = X_train['BldgTypeNumeric'].fillna(df['BldgTypeNumeric'].mean())
X_test['BldgTypeNumeric'] = X_test['BldgTypeNumeric'].fillna(df['BldgTypeNumeric'].mean())
df['BldgTypeNumeric'] = df['BldgTypeNumeric'].fillna(df['BldgTypeNumeric'].mean())

# %%
X_train['HouseStyleNumeric'] = X_train['HouseStyleNumeric'].fillna(df['HouseStyleNumeric'].mean())
X_test['HouseStyleNumeric'] = X_test['HouseStyleNumeric'].fillna(df['HouseStyleNumeric'].mean())
df['HouseStyleNumeric'] = df['HouseStyleNumeric'].fillna(df['HouseStyleNumeric'].mean())

# %%
X_train['LotConfigNumeric'] = X_train['LotConfigNumeric'].fillna(df['LotConfigNumeric'].mean())
X_test['LotConfigNumeric'] = X_test['LotConfigNumeric'].fillna(df['LotConfigNumeric'].mean())
df['LotConfigNumeric'] = df['LotConfigNumeric'].fillna(df['LotConfigNumeric'].mean())

# %%
#Интересующие столбцы для оценки
num_features = ['MSSubClass','ZoningNumeric', 'LotFrontage', 'LotArea', 'OverallQual', 
                'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 
                '1stFlrSF','2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 
                'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 
                'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 
                'GarageCars', 'GarageArea', 'WoodDeckSF','OpenPorchSF', 
                'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 
                'MiscVal', 'MoSold', 'YrSold','ZoningNumeric','StreetNumeric',
                'LotShapeNumeric',
                'UtilitiesNumeric','LotConfigNumeric','HouseStyleNumeric','BldgTypeNumeric']

# %%
df[num_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSSubClass         1000 non-null   int64
#  1   ZoningNumeric      1000 non-null   float64
#  2   LotFrontage        1000 non-null   float64
#  3   LotArea            1000 non-null   int64
#  4   OverallQual        1000 non-null   int64
#  5   OverallCond        1000 non-null   int64
#  6   YearBuilt          1000 non-null   int64
#  7   YearRemodAdd       1000 non-null   int64
#  8   MasVnrArea         1000 non-null   float64
#  9   1stFlrSF           1000 non-null   int64
#  10  2ndFlrSF           1000 non-null   int64
#  11  LowQualFinSF       1000 non-null   int64
#  12  GrLivArea          1000 non-null   int64
#  13  BsmtFullBath       1000 non-null   int64
#  14  BsmtHalfBath       1000 non-null   int64
#  15  FullBath           1000 non-null   int64
# ...

# %%
#Подключение линейной модели
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
#обучение на заранее подготовленных тренировочных данных
lin_reg.fit(X_train[num_features], y_train)
# Out:
# LinearRegression()

# %%
#Проверка на тестовых данных из первого файла train.csv
y_pred_train = lin_reg.predict(X_train[num_features])

# %%
#Получаем предсказание для набора на котором выполнялась тренировка (среднюю стоимость)
np.sqrt(mean_squared_error(y_train, y_pred_train))
# Out:
# np.float64(30511.977077576044)

# %%
y_pred = lin_reg.predict(X_test[num_features])

# %%
#проверяем предсказание на остатках от исходного набора (20% по умолчанию)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# np.float64(36940.13674200519)

# %%
#Далее подгружаем набор "диких" данных на которых необходимо провести оценку
df_t = pd.read_csv('test.csv')

# %%
#сверяем размерность
df_t.shape
# Out:
# (460, 80)

# %%
df_t.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1001          20       RL         74.0    10206   Pave   NaN      Reg
# 1  1002          30       RL         60.0     5400   Pave   NaN      Reg
# 2  1003          20       RL         75.0    11957   Pave   NaN      IR1
# 3  1004          90       RL          NaN    11500   Pave   NaN      IR1
# 4  1005         120       RL         43.0     3182   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 1         Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 2         Lvl    AllPub    Inside       Gtl      Somerst       RRAn
# 3         Lvl    AllPub    Corner       Gtl       NWAmes      Feedr
# 4         Lvl    AllPub    Inside       Gtl      Blmngtn       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Изучаем состав датафрейма по ВЫБРАННЫМ СТОЛБЦАМ
df_t['ZoningNumeric'] = df_t['MSZoning'].map(zoning_mapping)
df_t['StreetNumeric'] = df['Street'].map(street_mapping)
df_t['LotShapeNumeric'] = df['LotShape'].map(lotShape_mapping)
df_t['UtilitiesNumeric'] = df['Utilities'].map(utilities_mapping)
df_t['LotConfigNumeric'] = df['LotConfig'].map(lot_config_mapping)
df_t['HouseStyleNumeric'] = df['HouseStyle'].map(house_style_mapping)
df_t['BldgTypeNumeric'] = df['BldgType'].map(bldg_type_mapping)
df_t[num_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MSSubClass         460 non-null    int64
#  1   ZoningNumeric      458 non-null    float64
#  2   LotFrontage        374 non-null    float64
#  3   LotArea            460 non-null    int64
#  4   OverallQual        460 non-null    int64
#  5   OverallCond        460 non-null    int64
#  6   YearBuilt          460 non-null    int64
#  7   YearRemodAdd       460 non-null    int64
#  8   MasVnrArea         458 non-null    float64
#  9   1stFlrSF           460 non-null    int64
#  10  2ndFlrSF           460 non-null    int64
#  11  LowQualFinSF       460 non-null    int64
#  12  GrLivArea          460 non-null    int64
#  13  BsmtFullBath       460 non-null    int64
#  14  BsmtHalfBath       460 non-null    int64
#  15  FullBath           460 non-null    int64
# ...

# %%
#Заполняем пустые значения средним.
df_t['LotFrontage'] = df_t['LotFrontage'].fillna(df_t['LotFrontage'].mean())
df_t['MasVnrArea'] = df_t['MasVnrArea'].fillna(df_t['MasVnrArea'].mean())
df_t['GarageYrBlt'] = df_t['GarageYrBlt'].fillna(df_t['GarageYrBlt'].mean())
df_t['ZoningNumeric'] = df_t['ZoningNumeric'].fillna(df_t['ZoningNumeric'].mean())
df_t['LotConfigNumeric'] = df_t['LotConfigNumeric'].fillna(df_t['LotConfigNumeric'].mean())
df_t['HouseStyleNumeric'] = df_t['HouseStyleNumeric'].fillna(df_t['HouseStyleNumeric'].mean())
df_t['BldgTypeNumeric'] = df_t['BldgTypeNumeric'].fillna(df_t['BldgTypeNumeric'].mean())

# %%
#Предсказание по обученной модели и "реальному" датасету
y_pred = lin_reg.predict(df_t[num_features])

# %%
my_answ = pd.DataFrame(data=df_t['Id'])  #создаем новый датафрейм основываясь на первой колонке id
my_answ['SalePrice'] = pd.DataFrame(data=y_pred) #добавляем новую колонку и добавляем  значение преобразованное в датафрейм взятое из нашего предсказания
my_answ.head() #смотрим результат
# Out:
#      Id      SalePrice
# 0  1001   58452.813018
# 1  1002   67832.149474
# 2  1003  252135.844743
# 3  1004  151090.480595
# 4  1005  232205.352787

# %%
my_answ.to_csv('answer.csv',index=False)

# %% [markdown]
# 55411
# 62749
# 248057
# 150271
# 227470
