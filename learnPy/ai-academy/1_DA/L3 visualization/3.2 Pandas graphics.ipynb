# %%
 import pandas as pd
 df = pd.read_csv('Restaurant.csv')
 df.head()
# Out:
#    total_bill   tip     sex vegan  day    time  size
# 0       16.99  1.01  Female    No  Sun  Dinner     2
# 1       10.34  1.66    Male    No  Sun  Dinner     3
# 2       21.01  3.50    Male    No  Sun  Dinner     3
# 3       23.68  3.31    Male    No  Sun  Dinner     2
# 4       24.59  3.61  Female    No  Sun  Dinner     4

# %%
df.plot()
# Out:
# <Axes: >

# %%
 df["total_bill"].plot(kind = "hist") #Гистограмма по полю общий счет
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["total_bill"].plot(kind="hist", grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["total_bill"].plot(kind = "hist", title = "Общая сумма счета")
# Out:
# <Axes: title={'center': 'Общая сумма счета'}, ylabel='Frequency'>

# %%
df["total_bill"].plot(kind = "hist", grid=True, title = "Общая сумма счета")
# Out:
# <Axes: title={'center': 'Общая сумма счета'}, ylabel='Frequency'>

# %%
df["day"].value_counts().plot(kind = "bar", grid=True, colormap = "coolwarm", title = "Количество посетителей по дням")
# Out:
# <Axes: title={'center': 'Количество посетителей по дням'}, xlabel='day'>

# %%
df[["total_bill", "tip"]].plot(kind = "hist",
                               grid = True,
                               subplots = True,
                               title = ["Общая сумма счета","Сумма чаевых"],
                               legend = False)
# Out:
# array([<Axes: title={'center': 'Общая сумма счета'}, ylabel='Frequency'>,
#        <Axes: title={'center': 'Сумма чаевых'}, ylabel='Frequency'>],
#       dtype=object)

# %%
df.groupby('vegan')['tip'].count().plot(kind = 'bar')
# Out:
# <Axes: xlabel='vegan'>
